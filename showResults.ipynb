# %%
using Plots
using DelimitedFiles

# %%
datiRef=readdlm("../Notebooks/Check_chain_coeff/magMathe.csv", ',',Float64 , '\n');
datiMag = readdlm("Data/magMeas_TEBD.dat", ',', Complex{Float64}, '\n')
#datiMag = readdlm("Data/magMeas_TEBD.dat", ',', Float64, '\n')
plot(real(datiMag[:,1]), (1. .+real(datiMag[:,2])) ./2,label="TEBD")
plot!(datiRef[:,1],datiRef[:,2],label="Ref")

# %%
datiRefPop=readdlm("../Notebooks/Check_chain_coeff/popFirst.csv", ',',Float64 , '\n');
datiPop1 = readdlm("Data/popMeas_TEBD.dat", ',', Complex{Float64}, '\n')
#datiPop1 = readdlm("Data/popMeas_TEBD.dat", ',', Float64, '\n')
plot(real(datiPop1[:,1]), real(datiPop1[:,2]),label="TEBD")
plot!(datiRefPop[:,1],datiRefPop[:,2],label="Ref")

# %%
#
